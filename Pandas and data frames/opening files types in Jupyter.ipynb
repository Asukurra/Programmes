# %%
import os
import pandas
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'ipython and pandas.txt',
#  'nominatim bug work around',
#  'opening files types in Jupyter.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb']

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# had to pip install openpyxl to use with this
# sheet name is an index
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# this is passing the sep argument to show the programme its seperated by a ; not , as is default
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("supermarkets-commas.txt", header = None)
df6
# if you are loading data with no header (first row on the table with the names etc) then you need to tell this to Pandas with 
# whatever=pandas.read_csv("filename", header = None) - note the capital on None
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.columns = ["ID","Address","City","state", "Country","Name","Employees"]
df6
# you can set your own header names by passing a .columns argument with a list - this must match the length of the table
# Out:
#    ID          Address           City             state  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Employees
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.set_index("ID")
# you can change the index of the table by one of the columns with the .set_index("column name")
# note that this DOSNT change the dataframe - this will only change it for THIS call of the table
# Out:
#             Address           City             state  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#    ID          Address           City             state  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Employees
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
# note how the set_index has not been saved

# %%
# you can set a new dataframe to have this as a permament change by passing a new assignment 
df7 = df6.set_index("ID")
df7
# this adds a new 'blank' row on top
# Out:
#             Address           City             state  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# you can use drop=False to not remove the column you are using as index 
# you can use the inplace=True to save the dataframe over with the new index if needed
df7.set_index("City",inplace=True, drop=False)
df7
# Out:
#                        Address           City             state  Country  \
# City
# City                   Address           City             State  Country
# San Francisco     3666 21st St  San Francisco          CA 94114      USA
# San Francisco   735 Dolores St  San Francisco          CA 94119      USA
# San Francisco      332 Hill St  San Francisco  California 94114      USA
# San Francisco     3995 23rd St  San Francisco          CA 94114      USA
# San Francisco  1056 Sanchez St  San Francisco        California      USA
# San Francisco  551 Alvarado St  San Francisco          CA 94114      USA
#
#                       Name  Employees
# City
# City                  Name  Employees
# San Francisco      Madeira          8
# San Francisco  Bready Shop         15
# San Francisco  Super River         25
# San Francisco   Ben's Shop         10
# San Francisco      Sanchez         12
# San Francisco   Richvalley         20

# %%
# because I did NOT drop the "ID" in the previous table, I have lost this column

# %%
df6.loc["2":"4","state":"Name"]
#by using named indexing we can slice out parts of the tables by passing a list[start:stop,start:stop] for rows then columns
# Out:
#               state Country         Name
# 2          CA 94119     USA  Bready Shop
# 3  California 94114     USA  Super River
# 4          CA 94114     USA   Ben's Shop

# %%
df7.loc[:,"state"]
#or you can pass a blank arg for all of that paramater [:,columnName] - note the comma is important
# Out:
# City
# City                        State
# San Francisco            CA 94114
# San Francisco            CA 94119
# San Francisco    California 94114
# San Francisco            CA 94114
# San Francisco          California
# San Francisco            CA 94114
# Name: state, dtype: object

# %%
list(df7.loc[:,"state"])
#you can also add these into a list
# Out:
# ['State',
#  'CA 94114',
#  'CA 94119',
#  'California 94114',
#  'CA 94114',
#  'California',
#  'CA 94114']

# %%
df6.iloc[1:3:,1:3]
df6.iloc[1:4:,:4]
#using .iloc you can use index based searching like you would slice in normal python
# Out:
#   ID         Address           City             state
# 1  1    3666 21st St  San Francisco          CA 94114
# 2  2  735 Dolores St  San Francisco          CA 94119
# 3  3     332 Hill St  San Francisco  California 94114

# %%
df7.drop("state",1)
#using the .drop you can remove rows or columns - you specify the name of droped atribute then the second arg is 
# 0 for rows or 1 for columns
#note - this dosnt save the drop - only displays without the drop, same as the .set_index earlier
# Out:
#                        Address           City  Country         Name  Employees
# City
# City                   Address           City  Country         Name  Employees
# San Francisco     3666 21st St  San Francisco      USA      Madeira          8
# San Francisco   735 Dolores St  San Francisco      USA  Bready Shop         15
# San Francisco      332 Hill St  San Francisco      USA  Super River         25
# San Francisco     3995 23rd St  San Francisco      USA   Ben's Shop         10
# San Francisco  1056 Sanchez St  San Francisco      USA      Sanchez         12
# San Francisco  551 Alvarado St  San Francisco      USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# you can drop sliced sections by using the above syntax, the same rules of ,0 for rows and ,1 for columns 
#df7.drop(df7.index[0:3],0) for rows df7.drop(df7.columns[0:3],1) for columns
# Out:
# Empty DataFrame
# Columns: [Address, City, state, Country, Name, Employees]
# Index: []

# %%
df7=df7.set_index("Address",inplace=True, drop=False)

# %%
df6 = df6.set_index("Address",inplace=True, drop=False)

# %%
df6=pandas.read_csv("supermarkets-commas.txt", header = None)
df6
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.columns = ["ID","Address","City","state", "Country","Name","Employees"]
df6
# Out:
#    ID          Address           City             state  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Employees
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df7 = df6.set_index("Address")
df7
# Out:
#                  ID           City             state  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7["Continent"]=df7.shape[0]*["North America"]
df7
# Out:
#                  ID           City             state  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees      Continent
# Address
# Address          Employees  North America
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df7.shape
# Out:
# (7, 7)

# %%
# .shape give a tuple of the row:column - you need to pass an arguement for the total rows to add a column so by 
# using .shape[0] - the 0 index of the tuple - the number of rows - we can use that * to multiply the list values 
# effectively stateing the column name for every row

# %%
df7["Continent"] = df7["Country"]+ "," + "North America"
df7
# we can use concatination to reference an entire column and add a new value to it as the content for our new column
# Out:
#                  ID           City             state  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees              Continent
# Address
# Address          Employees  Country,North America
# 3666 21st St             8      USA,North America
# 735 Dolores St          15      USA,North America
# 332 Hill St             25      USA,North America
# 3995 23rd St            10      USA,North America
# ...

# %%
df7_t=df7.T

# %%
df7_t
# adding new rows is a bit tricky, we can use .T - transpose - to swap the rows and columns around
# Out:
# Address                  Address       3666 21st St     735 Dolores St  \
# ID                            ID                  1                  2
# City                        City      San Francisco      San Francisco
# state                      State           CA 94114           CA 94119
# Country                  Country                USA                USA
# Name                        Name            Madeira        Bready Shop
# Employees              Employees                  8                 15
# Continent  Country,North America  USA,North America  USA,North America
#
# Address          332 Hill St       3995 23rd St    1056 Sanchez St  \
# ID                         3                  4                  5
# City           San Francisco      San Francisco      San Francisco
# state       California 94114           CA 94114         California
# Country                  USA                USA                USA
# ...

# %%
df7_t["My Address"]=["My City","My Country",10,7,"My Shop","My continent","somthing else"]

# %%
df7=df7_t.T

# %%
df7
# Out:
#                       ID           City             state  Country  \
# Address
# Address               ID           City             State  Country
# 3666 21st St           1  San Francisco          CA 94114      USA
# 735 Dolores St         2  San Francisco          CA 94119      USA
# 332 Hill St            3  San Francisco  California 94114      USA
# 3995 23rd St           4  San Francisco          CA 94114      USA
# 1056 Sanchez St        5  San Francisco        California      USA
# 551 Alvarado St        6  San Francisco          CA 94114      USA
# My Address       My City     My Country                10        7
#
#                         Name     Employees              Continent
# Address
# Address                 Name     Employees  Country,North America
# 3666 21st St         Madeira             8      USA,North America
# 735 Dolores St   Bready Shop            15      USA,North America
# 332 Hill St      Super River            25      USA,North America
# ...

# %%
# using the above, we swap rows and colums, add a new colum and pass all the needed arguments to match the rows
#then set the orgional value as the new transposed values then transpose them back
